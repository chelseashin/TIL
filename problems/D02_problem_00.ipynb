# %% [markdown]
# # 가상화폐 시세 판단하기

# %% [markdown]
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# |Key Name        |     Description|
# |---|---|
# |opeing_price    |최근 24시간 내 시작 거래금액|
# |closing_price   |최근 24시간 내 마지막 거래금액|
# |min_price       |최근 24시간 내 최저 거래금액|
# |max_price       |최근 24시간 내 최고 거래금액|

# %%
import requests
from pprint import pprint
btc = requests.get('https://api.bithumb.com/public/ticker/btc').json()['data']
pprint(btc)

# pprint 사용하여 더 쉽게 내용 보기!
# Out:
# {'24H_fluctate': '-22000',
#  '24H_fluctate_rate': '-0.50',
#  'average_price': '4307588.448',
#  'buy_price': '4292000',
#  'closing_price': '4293000',
#  'date': '1546762939458',
#  'max_price': '4351000',
#  'min_price': '4269000',
#  'opening_price': '4315000',
#  'sell_price': '4293000',
#  'units_traded': '19921.28934084',
#  'volume_1day': '19921.28934084',
#  'volume_7day': '91870.8952106'}

# %%
print(btc['max_price'])
print(btc['min_price'])
print(type(btc['max_price']))
# Out:
# 4351000
# 4269000
# <class 'str'>

# %%
# 나의 풀이
diff = int(btc['max_price']) - int(btc['min_price'])
siga = int(btc['opening_price'])
plus = diff + siga

if plus >= int(btc['max_price']):
    print("상승장")
else:
    print("하락장")
# Out:
# 상승장

# %%
# 좋은 풀이
bdp = int(btc['max_price'])- int(btc['min_price'])

if int(btc['opening_price']) + bdp > int(btc['max_price']):
    print('상승장')
else:
    print('하락장')
# Out:
# 상승장

# %% [markdown]
# ## 모든 가상화폐 시세 판단하기
#
#
# > currrency dictionary에 담겨있는 모든 가상화폐 거래내역을 바탕으로 출력하라.
# >
# > 예외 처리에 유의하세요.
#
#
#
# ```
# 예시 출력)
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 하락장
# ETC 하락장
# XRP 상승장
# BCH 상승장
# ...
# ```

# %%
from pprint import pprint

currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
pprint(currency)
# Out:
# {'ABT': {'24H_fluctate': '-1.4',
#          '24H_fluctate_rate': '-1.52',
#          'average_price': '90.6377',
#          'buy_price': '90.4',
#          'closing_price': '90.5',
#          'max_price': '92.9',
#          'min_price': '86.5',
#          'opening_price': '91.9',
#          'sell_price': '91.2',
#          'units_traded': '1229767.29325293',
#          'volume_1day': '1229767.29325293',
#          'volume_7day': '54612530.076146308094807586'},
#  'ADA': {'24H_fluctate': '6.2',
#          '24H_fluctate_rate': '8.05',
#          'average_price': '80.9455',
#          'buy_price': '83',
#          'closing_price': '83.2',
#          'max_price': '85.3',
#          'min_price': '76',
#          'opening_price': '77',
#          'sell_price': '83.2',
#          'units_traded': '37820407.58451112',
#          'volume_1day': '37820407.58451112',
#          'volume_7day': '54510252.6508456'},
#  'ADD': [],
#  'AE': {'24H_fluctate': '-45',
#         '24H_fluctate_rate': '-2.91',
#         'average_price': '1496.1085',
#         'buy_price': '1501',
#         'closing_price': '1501',
#         'max_price': '1547',
#         'min_price': '1455',
#         'opening_price': '1546',
#         'sell_price': '1508',
#         'units_traded': '56509.35182772',
#         'volume_1day': '56509.35182772',
#         'volume_7day': '748666.67069164693885174'},
#  'AMO': {'24H_fluctate': '-0.06',
#          '24H_fluctate_rate': '-4.16',
#          'average_price': '1.4017',
#          'buy_price': '1.37',
#          'closing_price': '1.38',
#          'max_price': '1.49',
#          'min_price': '1.33',
#          'opening_price': '1.44',
#          'sell_price': '1.38',
#          'units_traded': '395318435.18926403',
#          'volume_1day': '395318435.18926403',
#          'volume_7day': '25426892630.563890541795020498'},
#  'BAT': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-0.65',
#          'average_price': '152.7314',
#          'buy_price': '151',
#          'closing_price': '152',
#          'max_price': '157',
#          'min_price': '150',
#          'opening_price': '153',
#          'sell_price': '153',
#          'units_traded': '654604.7153129',
#          'volume_1day': '654604.7153129',
#          'volume_7day': '11108013.92637440220588544'},
#  'BCD': {'24H_fluctate': '78',
#          '24H_fluctate_rate': '7.77',
#          'average_price': '1062.8513',
#          'buy_price': '1073',
#          'closing_price': '1081',
#          'max_price': '1150',
#          'min_price': '1000',
#          'opening_price': '1003',
#          'sell_price': '1081',
#          'units_traded': '429331.22910445',
#          'volume_1day': '429331.22910445',
#          'volume_7day': '1542885.24086721'},
#  'BCH': {'24H_fluctate': '2400',
#          '24H_fluctate_rate': '1.35',
#          'average_price': '180305.5501',
#          'buy_price': '178600',
#          'closing_price': '179000',
#          'max_price': '186200',
#          'min_price': '175400',
#          'opening_price': '176600',
#          'sell_price': '179000',
#          'units_traded': '34805.06672542',
#          'volume_1day': '34805.06672542',
#          'volume_7day': '376500.40872308'},
#  'BHPC': {'24H_fluctate': '-38',
#           '24H_fluctate_rate': '-4.29',
#           'average_price': '859.4009',
#           'buy_price': '840',
#           'closing_price': '846',
#           'max_price': '890',
#           'min_price': '827',
#           'opening_price': '884',
#           'sell_price': '846',
#           'units_traded': '335973.79354432',
#           'volume_1day': '335973.79354432',
#           'volume_7day': '4201211.301978976008354378'},
#  'BLACK': [],
#  'BSV': {'24H_fluctate': '1600',
#          '24H_fluctate_rate': '1.64',
#          'average_price': '99483.5718',
#          'buy_price': '98400',
#          'closing_price': '98600',
#          'max_price': '102900',
#          'min_price': '96250',
#          'opening_price': '97000',
#          'sell_price': '98600',
#          'units_traded': '21359.4355385',
#          'volume_1day': '21359.4355385',
#          'volume_7day': '211356.6861842'},
#  'BTC': {'24H_fluctate': '-22000',
#          '24H_fluctate_rate': '-0.50',
#          'average_price': '4307588.448',
#          'buy_price': '4292000',
#          'closing_price': '4293000',
#          'max_price': '4351000',
#          'min_price': '4269000',
#          'opening_price': '4315000',
#          'sell_price': '4293000',
#          'units_traded': '19921.28934084',
#          'volume_1day': '19921.28934084',
#          'volume_7day': '91870.8952106'},
#  'BTG': {'24H_fluctate': '-60',
#          '24H_fluctate_rate': '-0.41',
#          'average_price': '14498.729',
#          'buy_price': '14440',
#          'closing_price': '14440',
#          'max_price': '14590',
#          'min_price': '14310',
#          'opening_price': '14500',
#          'sell_price': '14490',
#          'units_traded': '16697933.17361039',
#          'volume_1day': '16697933.17361039',
#          'volume_7day': '120817940.74730103'},
#  'BZNT': {'24H_fluctate': '-0.3',
#           '24H_fluctate_rate': '-1.09',
#           'average_price': '27.3982',
#           'buy_price': '27.1',
#           'closing_price': '27.1',
#           'max_price': '28.2',
#           'min_price': '26.7',
#           'opening_price': '27.4',
#           'sell_price': '27.2',
#           'units_traded': '40810012.60222424',
#           'volume_1day': '40810012.60222424',
#           'volume_7day': '236755837.864555075912919761'},
#  'CHL': [],
#  'CMT': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '33.9018',
#          'buy_price': '33.6',
#          'closing_price': '33.5',
#          'max_price': '34.9',
#          'min_price': '32.8',
#          'opening_price': '33.5',
#          'sell_price': '34.1',
#          'units_traded': '1765801.14092507',
#          'volume_1day': '1765801.14092507',
#          'volume_7day': '26553210.714031699396034533'},
#  'CTXC': {'24H_fluctate': '17',
#           '24H_fluctate_rate': '14.52',
#           'average_price': '131.7462',
#           'buy_price': '134',
#           'closing_price': '134',
#           'max_price': '148',
#           'min_price': '116',
#           'opening_price': '117',
#           'sell_price': '135',
#           'units_traded': '13689920.81430057',
#           'volume_1day': '13689920.81430057',
#           'volume_7day': '20582361.575669314730713655'},
#  'DASH': {'24H_fluctate': '-450',
#           '24H_fluctate_rate': '-0.49',
#           'average_price': '89642.2194',
#           'buy_price': '89300',
#           'closing_price': '89600',
#           'max_price': '91050',
#           'min_price': '88600',
#           'opening_price': '90050',
#           'sell_price': '89500',
#           'units_traded': '4089718.95060572',
#           'volume_1day': '4089718.95060572',
#           'volume_7day': '29643805.95865686'},
#  'ELF': {'24H_fluctate': '1',
#          '24H_fluctate_rate': '0.75',
#          'average_price': '132.3921',
#          'buy_price': '133',
#          'closing_price': '134',
#          'max_price': '135',
#          'min_price': '130',
#          'opening_price': '133',
#          'sell_price': '134',
#          'units_traded': '966371.8588',
#          'volume_1day': '966371.8588',
#          'volume_7day': '19236796.880052265081801359'},
#  'ENJ': {'24H_fluctate': '-1.4',
#          '24H_fluctate_rate': '-3.26',
#          'average_price': '42.1957',
#          'buy_price': '41.4',
#          'closing_price': '41.5',
#          'max_price': '43.6',
#          'min_price': '41.2',
#          'opening_price': '42.9',
#          'sell_price': '41.9',
#          'units_traded': '1688915.62652401',
#          'volume_1day': '1688915.62652401',
#          'volume_7day': '17591627.773105662913581526'},
#  'EOS': {'24H_fluctate': '-23',
#          '24H_fluctate_rate': '-0.76',
#          'average_price': '3022.3997',
#          'buy_price': '2990',
#          'closing_price': '2990',
#          'max_price': '3085',
#          'min_price': '2965',
#          'opening_price': '3013',
#          'sell_price': '2994',
#          'units_traded': '1563294.38941196',
#          'volume_1day': '1563294.38941196',
#          'volume_7day': '19744253.68625633'},
#  'EOSDAC': [],
#  'ETC': {'24H_fluctate': '20',
#          '24H_fluctate_rate': '0.34',
#          'average_price': '5803.0444',
#          'buy_price': '5795',
#          'closing_price': '5800',
#          'max_price': '5895',
#          'min_price': '5715',
#          'opening_price': '5780',
#          'sell_price': '5800',
#          'units_traded': '179037.43513871',
#          'volume_1day': '179037.43513871',
#          'volume_7day': '1502317.627635475096835958'},
#  'ETH': {'24H_fluctate': '-4600',
#          '24H_fluctate_rate': '-2.62',
#          'average_price': '174032.0285',
#          'buy_price': '170600',
#          'closing_price': '170700',
#          'max_price': '178300',
#          'min_price': '168300',
#          'opening_price': '175300',
#          'sell_price': '170700',
#          'units_traded': '387305.81649341',
#          'volume_1day': '387305.81649341',
#          'volume_7day': '2610703.263192550329706921'},
#  'ETHOS': {'24H_fluctate': '-33',
#            '24H_fluctate_rate': '-3.13',
#            'average_price': '1025.8886',
#            'buy_price': '1020',
#            'closing_price': '1020',
#            'max_price': '1072',
#            'min_price': '989',
#            'opening_price': '1053',
#            'sell_price': '1025',
#            'units_traded': '85090.5520466',
#            'volume_1day': '85090.5520466',
#            'volume_7day': '2408182.3574623'},
#  'GNT': {'24H_fluctate': '-0.59',
#          '24H_fluctate_rate': '-0.75',
#          'average_price': '78.6627',
#          'buy_price': '78.4',
#          'closing_price': '78.7',
#          'max_price': '79.7',
#          'min_price': '77.8',
#          'opening_price': '79.3',
#          'sell_price': '78.7',
#          'units_traded': '2142932.51659971',
#          'volume_1day': '2142932.51659971',
#          'volume_7day': '29890529.32282884764448333'},
#  'GTO': {'24H_fluctate': '1.4',
#          '24H_fluctate_rate': '1.94',
#          'average_price': '73.5345',
#          'buy_price': '72.3',
#          'closing_price': '73.3',
#          'max_price': '76.9',
#          'min_price': '71.7',
#          'opening_price': '71.9',
#          'sell_price': '73.1',
#          'units_traded': '1622612.61986281',
#          'volume_1day': '1622612.61986281',
#          'volume_7day': '11482430.58577709'},
#  'HC': {'24H_fluctate': '12',
#         '24H_fluctate_rate': '0.85',
#         'average_price': '1392.2699',
#         'buy_price': '1388',
#         'closing_price': '1416',
#         'max_price': '1421',
#         'min_price': '1371',
#         'opening_price': '1404',
#         'sell_price': '1416',
#         'units_traded': '36534.9604728',
#         'volume_1day': '36534.9604728',
#         'volume_7day': '453418.41365085'},
#  'HORUS': [],
#  'ICX': {'24H_fluctate': '-12',
#          '24H_fluctate_rate': '-3.88',
#          'average_price': '303.6112',
#          'buy_price': '296',
#          'closing_price': '297',
#          'max_price': '313',
#          'min_price': '294',
#          'opening_price': '309',
#          'sell_price': '297',
#          'units_traded': '1606944.71577153',
#          'volume_1day': '1606944.71577153',
#          'volume_7day': '10483818.857102372293254136'},
#  'INS': {'24H_fluctate': '-2',
#          '24H_fluctate_rate': '-0.58',
#          'average_price': '338.483',
#          'buy_price': '337',
#          'closing_price': '338',
#          'max_price': '347',
#          'min_price': '331',
#          'opening_price': '340',
#          'sell_price': '338',
#          'units_traded': '804224.57266492',
#          'volume_1day': '804224.57266492',
#          'volume_7day': '16751766.5806462393'},
#  'IOST': {'24H_fluctate': '-0.02',
#           '24H_fluctate_rate': '-0.30',
#           'average_price': '6.4886',
#           'buy_price': '6.45',
#           'closing_price': '6.49',
#           'max_price': '6.58',
#           'min_price': '6.4',
#           'opening_price': '6.51',
#           'sell_price': '6.49',
#           'units_traded': '336104971.45920703',
#           'volume_1day': '336104971.45920703',
#           'volume_7day': '2117215480.553122129697478645'},
#  'ITC': {'24H_fluctate': '6',
#          '24H_fluctate_rate': '4.44',
#          'average_price': '146.5436',
#          'buy_price': '141',
#          'closing_price': '141',
#          'max_price': '160',
#          'min_price': '133',
#          'opening_price': '135',
#          'sell_price': '142',
#          'units_traded': '11616595.87135393',
#          'volume_1day': '11616595.87135393',
#          'volume_7day': '20780218.097756271028698473'},
#  'KNC': {'24H_fluctate': '4',
#          '24H_fluctate_rate': '2.25',
#          'average_price': '179.7298',
#          'buy_price': '181',
#          'closing_price': '181',
#          'max_price': '183',
#          'min_price': '176',
#          'opening_price': '177',
#          'sell_price': '182',
#          'units_traded': '748594.72962003',
#          'volume_1day': '748594.72962003',
#          'volume_7day': '5719285.335866835077650867'},
#  'LINK': {'24H_fluctate': '-23',
#           '24H_fluctate_rate': '-5.11',
#           'average_price': '439.9188',
#           'buy_price': '427',
#           'closing_price': '427',
#           'max_price': '464',
#           'min_price': '415',
#           'opening_price': '450',
#           'sell_price': '429',
#           'units_traded': '2370393.59147702',
#           'volume_1day': '2370393.59147702',
#           'volume_7day': '35635905.724757868423999445'},
#  'LOOM': {'24H_fluctate': '-2.7',
#           '24H_fluctate_rate': '-4.77',
#           'average_price': '53.7198',
#           'buy_price': '52.7',
#           'closing_price': '53.9',
#           'max_price': '56.6',
#           'min_price': '52.3',
#           'opening_price': '56.6',
#           'sell_price': '53.9',
#           'units_traded': '1480031.26880028',
#           'volume_1day': '1480031.26880028',
#           'volume_7day': '50191524.1567069619633693'},
#  'LRC': {'24H_fluctate': '-25',
#          '24H_fluctate_rate': '-4.67',
#          'average_price': '523.7737',
#          'buy_price': '512',
#          'closing_price': '510',
#          'max_price': '597',
#          'min_price': '410',
#          'opening_price': '535',
#          'sell_price': '519',
#          'units_traded': '430497.87867894',
#          'volume_1day': '430497.87867894',
#          'volume_7day': '2128706.124144714724835236'},
#  'LTC': {'24H_fluctate': '2490',
#          '24H_fluctate_rate': '6.71',
#          'average_price': '39412.4372',
#          'buy_price': '39530',
#          'closing_price': '39580',
#          'max_price': '40780',
#          'min_price': '36750',
#          'opening_price': '37090',
#          'sell_price': '39630',
#          'units_traded': '47745.40889459',
#          'volume_1day': '47745.40889459',
#          'volume_7day': '198174.94804281'},
#  'MCO': {'24H_fluctate': '-242',
#          '24H_fluctate_rate': '-7.85',
#          'average_price': '2983.2037',
#          'buy_price': '2829',
#          'closing_price': '2838',
#          'max_price': '3150',
#          'min_price': '2801',
#          'opening_price': '3080',
#          'sell_price': '2838',
#          'units_traded': '1145373.01794541',
#          'volume_1day': '1145373.01794541',
#          'volume_7day': '4210176.37660655'},
#  'MEETONE': [],
#  'MITH': {'24H_fluctate': '0.1',
#           '24H_fluctate_rate': '0.14',
#           'average_price': '69.4264',
#           'buy_price': '69.4',
#           'closing_price': '69.4',
#           'max_price': '70.2',
#           'min_price': '68.7',
#           'opening_price': '69.3',
#           'sell_price': '69.6',
#           'units_traded': '7174819.52658448',
#           'volume_1day': '7174819.52658448',
#           'volume_7day': '80037955.637529369607491297'},
#  'OCN': {'24H_fluctate': '0.22',
#          '24H_fluctate_rate': '5.94',
#          'average_price': '3.8603',
#          'buy_price': '3.84',
#          'closing_price': '3.92',
#          'max_price': '4.01',
#          'min_price': '3.7',
#          'opening_price': '3.7',
#          'sell_price': '3.91',
#          'units_traded': '73565342.85150847',
#          'volume_1day': '73565342.85150847',
#          'volume_7day': '1200342789.020678198262147727'},
#  'OMG': {'24H_fluctate': '-19',
#          '24H_fluctate_rate': '-1.12',
#          'average_price': '1675.9267',
#          'buy_price': '1660',
#          'closing_price': '1669',
#          'max_price': '1736',
#          'min_price': '1650',
#          'opening_price': '1688',
#          'sell_price': '1669',
#          'units_traded': '12306786.25137194',
#          'volume_1day': '12306786.25137194',
#          'volume_7day': '28207862.376053596277862803'},
#  'PAY': {'24H_fluctate': '-69',
#          '24H_fluctate_rate': '-4.25',
#          'average_price': '1568.8076',
#          'buy_price': '1549',
#          'closing_price': '1552',
#          'max_price': '1621',
#          'min_price': '1490',
#          'opening_price': '1621',
#          'sell_price': '1551',
#          'units_traded': '188306.6784749',
#          'volume_1day': '188306.6784749',
#          'volume_7day': '3953715.652987469950620253'},
#  'PIVX': {'24H_fluctate': '-74',
#           '24H_fluctate_rate': '-6.92',
#           'average_price': '1033.4966',
#           'buy_price': '981',
#           'closing_price': '995',
#           'max_price': '1150',
#           'min_price': '940',
#           'opening_price': '1069',
#           'sell_price': '991',
#           'units_traded': '1004467.74878113',
#           'volume_1day': '1004467.74878113',
#           'volume_7day': '6325991.50865589'},
#  'PLY': {'24H_fluctate': '2.6',
#          '24H_fluctate_rate': '7.28',
#          'average_price': '37.9616',
#          'buy_price': '38.3',
#          'closing_price': '38.3',
#          'max_price': '39.4',
#          'min_price': '35.5',
#          'opening_price': '35.7',
#          'sell_price': '38.6',
#          'units_traded': '12387202.80226617',
#          'volume_1day': '12387202.80226617',
#          'volume_7day': '98533615.358653742'},
#  'POLY': {'24H_fluctate': '-2',
#           '24H_fluctate_rate': '-1.28',
#           'average_price': '155.5964',
#           'buy_price': '153',
#           'closing_price': '154',
#           'max_price': '158',
#           'min_price': '153',
#           'opening_price': '156',
#           'sell_price': '154',
#           'units_traded': '556314.78874726',
#           'volume_1day': '556314.78874726',
#           'volume_7day': '7162697.539977591935317262'},
#  'POWR': {'24H_fluctate': '-9',
#           '24H_fluctate_rate': '-1.84',
#           'average_price': '478.3185',
#           'buy_price': '479',
#           'closing_price': '479',
#           'max_price': '503',
#           'min_price': '454',
#           'opening_price': '488',
#           'sell_price': '486',
#           'units_traded': '463198.47525676',
#           'volume_1day': '463198.47525676',
#           'volume_7day': '4088715.6125934'},
#  'PPT': {'24H_fluctate': '21',
#          '24H_fluctate_rate': '1.25',
#          'average_price': '1746.1413',
#          'buy_price': '1678',
#          'closing_price': '1699',
#          'max_price': '1919',
#          'min_price': '1635',
#          'opening_price': '1678',
#          'sell_price': '1699',
#          'units_traded': '300976.26596722',
#          'volume_1day': '300976.26596722',
#          'volume_7day': '687740.35436742'},
#  'PST': {'24H_fluctate': '42',
#          '24H_fluctate_rate': '38.18',
#          'average_price': '148.387',
#          'buy_price': '151',
#          'closing_price': '152',
#          'max_price': '178',
#          'min_price': '109',
#          'opening_price': '110',
#          'sell_price': '152',
#          'units_traded': '26680178.93725865',
#          'volume_1day': '26680178.93725865',
#          'volume_7day': '34288188.109710059157860587'},
#  'QTUM': {'24H_fluctate': '-21',
#           '24H_fluctate_rate': '-0.83',
#           'average_price': '2520.7361',
#           'buy_price': '2495',
#           'closing_price': '2499',
#           'max_price': '2561',
#           'min_price': '2485',
#           'opening_price': '2520',
#           'sell_price': '2499',
#           'units_traded': '315160.07063675',
#           'volume_1day': '315160.07063675',
#           'volume_7day': '2665322.78697243'},
#  'RDN': {'24H_fluctate': '-10',
#          '24H_fluctate_rate': '-3.37',
#          'average_price': '287.5996',
#          'buy_price': '286',
#          'closing_price': '286',
#          'max_price': '297',
#          'min_price': '279',
#          'opening_price': '296',
#          'sell_price': '289',
#          'units_traded': '785293.15244759',
#          'volume_1day': '785293.15244759',
#          'volume_7day': '25729171.722081401776233842'},
#  'REP': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '94386.298',
#          'buy_price': '93800',
#          'closing_price': '94500',
#          'max_price': '95800',
#          'min_price': '92400',
#          'opening_price': '94500',
#          'sell_price': '94500',
#          'units_traded': '2473.15447313',
#          'volume_1day': '2473.15447313',
#          'volume_7day': '35353.736820526256274038'},
#  'RNT': {'24H_fluctate': '-5',
#          '24H_fluctate_rate': '-4.62',
#          'average_price': '104.2148',
#          'buy_price': '102',
#          'closing_price': '103',
#          'max_price': '112',
#          'min_price': '99.6',
#          'opening_price': '108',
#          'sell_price': '103',
#          'units_traded': '35094420.95260791',
#          'volume_1day': '35094420.95260791',
#          'volume_7day': '361278375.835746599046495505'},
#  'ROM': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '0.1277',
#          'buy_price': '0.12',
#          'closing_price': '0.12',
#          'max_price': '0.13',
#          'min_price': '0.12',
#          'opening_price': '0.12',
#          'sell_price': '0.13',
#          'units_traded': '2766460608.34219231',
#          'volume_1day': '2766460608.34219231',
#          'volume_7day': '274105340457.145830378301879155'},
#  'SALT': {'24H_fluctate': '5',
#           '24H_fluctate_rate': '1.91',
#           'average_price': '272.4097',
#           'buy_price': '266',
#           'closing_price': '266',
#           'max_price': '291',
#           'min_price': '261',
#           'opening_price': '261',
#           'sell_price': '268',
#           'units_traded': '2054377.14528654',
#           'volume_1day': '2054377.14528654',
#           'volume_7day': '13181222.16081156'},
#  'SNT': {'24H_fluctate': '9',
#          '24H_fluctate_rate': '7.96',
#          'average_price': '120.0098',
#          'buy_price': '122',
#          'closing_price': '122',
#          'max_price': '127',
#          'min_price': '113',
#          'opening_price': '113',
#          'sell_price': '123',
#          'units_traded': '5162547.79203087',
#          'volume_1day': '5162547.79203087',
#          'volume_7day': '15559015.912003176632827563'},
#  'STEEM': {'24H_fluctate': '26',
#            '24H_fluctate_rate': '1.48',
#            'average_price': '1766.5472',
#            'buy_price': '1756',
#            'closing_price': '1776',
#            'max_price': '1800',
#            'min_price': '1748',
#            'opening_price': '1750',
#            'sell_price': '1776',
#            'units_traded': '13990.5757435',
#            'volume_1day': '13990.5757435',
#            'volume_7day': '537844.99582416'},
#  'STRAT': {'24H_fluctate': '-80',
#            '24H_fluctate_rate': '-2.87',
#            'average_price': '2653.0507',
#            'buy_price': '2631',
#            'closing_price': '2700',
#            'max_price': '2781',
#            'min_price': '2525',
#            'opening_price': '2780',
#            'sell_price': '2700',
#            'units_traded': '29563.20048446',
#            'volume_1day': '29563.20048446',
#            'volume_7day': '257326.22681759'},
#  'THETA': {'24H_fluctate': '-0.2',
#            '24H_fluctate_rate': '-0.35',
#            'average_price': '55.9536',
#            'buy_price': '55.5',
#            'closing_price': '55.7',
#            'max_price': '56.7',
#            'min_price': '55.3',
#            'opening_price': '55.9',
#            'sell_price': '55.9',
#            'units_traded': '2621076.39558301',
#            'volume_1day': '2621076.39558301',
#            'volume_7day': '54079288.008452585896573779'},
#  'TMTG': {'24H_fluctate': '0.02',
#           '24H_fluctate_rate': '0.24',
#           'average_price': '8.0173',
#           'buy_price': '8.06',
#           'closing_price': '8.08',
#           'max_price': '8.35',
#           'min_price': '7.83',
#           'opening_price': '8.06',
#           'sell_price': '8.08',
#           'units_traded': '348006629.05584962',
#           'volume_1day': '348006629.05584962',
#           'volume_7day': '1640357412.737364165635261096'},
#  'TRUE': {'24H_fluctate': '11',
#           '24H_fluctate_rate': '3.72',
#           'average_price': '301.3763',
#           'buy_price': '299',
#           'closing_price': '306',
#           'max_price': '310',
#           'min_price': '289',
#           'opening_price': '295',
#           'sell_price': '306',
#           'units_traded': '516023.78360839',
#           'volume_1day': '516023.78360839',
#           'volume_7day': '8934342.003018382708610936'},
#  'TRX': {'24H_fluctate': '0.7',
#          '24H_fluctate_rate': '2.86',
#          'average_price': '25.2366',
#          'buy_price': '25.1',
#          'closing_price': '25.1',
#          'max_price': '26.4',
#          'min_price': '24.3',
#          'opening_price': '24.4',
#          'sell_price': '25.2',
#          'units_traded': '309294866.25070854',
#          'volume_1day': '309294866.25070854',
#          'volume_7day': '1158617823.56457529'},
#  'VET': {'24H_fluctate': '0.08',
#          '24H_fluctate_rate': '1.12',
#          'average_price': '7.1604',
#          'buy_price': '7.15',
#          'closing_price': '7.18',
#          'max_price': '7.3',
#          'min_price': '7.07',
#          'opening_price': '7.1',
#          'sell_price': '7.18',
#          'units_traded': '3480136.29701858',
#          'volume_1day': '3480136.29701858',
#          'volume_7day': '47542732.488204709878489679'},
#  'WAVES': {'24H_fluctate': '-34',
#            '24H_fluctate_rate': '-0.99',
#            'average_price': '3433.5311',
#            'buy_price': '3391',
#            'closing_price': '3396',
#            'max_price': '3469',
#            'min_price': '3360',
#            'opening_price': '3430',
#            'sell_price': '3425',
#            'units_traded': '466575.89822281',
#            'volume_1day': '466575.89822281',
#            'volume_7day': '2823527.4697019'},
#  'WAX': {'24H_fluctate': '3',
#          '24H_fluctate_rate': '2.88',
#          'average_price': '109.2535',
#          'buy_price': '106',
#          'closing_price': '107',
#          'max_price': '118',
#          'min_price': '102',
#          'opening_price': '104',
#          'sell_price': '107',
#          'units_traded': '4318330.23457222',
#          'volume_1day': '4318330.23457222',
#          'volume_7day': '10320945.07737917'},
#  'WET': {'24H_fluctate': '0.4',
#          '24H_fluctate_rate': '2.89',
#          'average_price': '14.4834',
#          'buy_price': '14.2',
#          'closing_price': '14.2',
#          'max_price': '15.1',
#          'min_price': '13.7',
#          'opening_price': '13.8',
#          'sell_price': '14.3',
#          'units_traded': '52563368.94360514',
#          'volume_1day': '52563368.94360514',
#          'volume_7day': '194317644.198748709737311994'},
#  'WTC': {'24H_fluctate': '19',
#          '24H_fluctate_rate': '1.50',
#          'average_price': '1286.4393',
#          'buy_price': '1271',
#          'closing_price': '1281',
#          'max_price': '1340',
#          'min_price': '1243',
#          'opening_price': '1262',
#          'sell_price': '1283',
#          'units_traded': '150791.60086305',
#          'volume_1day': '150791.60086305',
#          'volume_7day': '1699695.503687578885323057'},
#  'XEM': {'24H_fluctate': '0.59',
#          '24H_fluctate_rate': '0.83',
#          'average_price': '72.3789',
#          'buy_price': '72.3',
#          'closing_price': '72.3',
#          'max_price': '74.6',
#          'min_price': '71.5',
#          'opening_price': '71.7',
#          'sell_price': '72.7',
#          'units_traded': '1150449.69296492',
#          'volume_1day': '1150449.69296492',
#          'volume_7day': '16455083.64345074'},
#  'XLM': {'24H_fluctate': '-2',
#          '24H_fluctate_rate': '-1.56',
#          'average_price': '127.5492',
#          'buy_price': '127',
#          'closing_price': '126',
#          'max_price': '129',
#          'min_price': '126',
#          'opening_price': '128',
#          'sell_price': '128',
#          'units_traded': '3831502.16265678',
#          'volume_1day': '3831502.16265678',
#          'volume_7day': '33117605.82420623'},
#  'XMR': {'24H_fluctate': '-800',
#          '24H_fluctate_rate': '-1.40',
#          'average_price': '55978.441',
#          'buy_price': '55900',
#          'closing_price': '55950',
#          'max_price': '57100',
#          'min_price': '55150',
#          'opening_price': '56750',
#          'sell_price': '55950',
#          'units_traded': '13877782.03220731',
#          'volume_1day': '13877782.03220731',
#          'volume_7day': '85444311.553511623238'},
#  'XRP': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-0.25',
#          'average_price': '399.3204',
#          'buy_price': '397',
#          'closing_price': '397',
#          'max_price': '405',
#          'min_price': '395',
#          'opening_price': '398',
#          'sell_price': '398',
#          'units_traded': '31144822.51642185',
#          'volume_1day': '31144822.51642185',
#          'volume_7day': '342836116.16366557'},
#  'XVG': {'24H_fluctate': '0.1',
#          '24H_fluctate_rate': '1.30',
#          'average_price': '7.9063',
#          'buy_price': '7.76',
#          'closing_price': '7.77',
#          'max_price': '8.28',
#          'min_price': '7.67',
#          'opening_price': '7.67',
#          'sell_price': '7.88',
#          'units_traded': '12111031.86571013',
#          'volume_1day': '12111031.86571013',
#          'volume_7day': '59126603.98991977'},
#  'ZEC': {'24H_fluctate': '-700',
#          '24H_fluctate_rate': '-1.07',
#          'average_price': '66270.0505',
#          'buy_price': '64400',
#          'closing_price': '64700',
#          'max_price': '66950',
#          'min_price': '63800',
#          'opening_price': '65400',
#          'sell_price': '64600',
#          'units_traded': '668643.03853151',
#          'volume_1day': '668643.03853151',
#          'volume_7day': '14770168.22083555'},
#  'ZIL': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '22.9126',
#          'buy_price': '22.8',
#          'closing_price': '22.8',
#          'max_price': '23.3',
#          'min_price': '22.6',
#          'opening_price': '22.8',
#          'sell_price': '22.9',
#          'units_traded': '21935170.32558156',
#          'volume_1day': '21935170.32558156',
#          'volume_7day': '268681716.335373643711'},
#  'ZRX': {'24H_fluctate': '3',
#          '24H_fluctate_rate': '0.83',
#          'average_price': '361.4361',
#          'buy_price': '363',
#          'closing_price': '364',
#          'max_price': '365',
#          'min_price': '357',
#          'opening_price': '361',
#          'sell_price': '364',
#          'units_traded': '456987.6221099',
#          'volume_1day': '456987.6221099',
#          'volume_7day': '4254198.76801030024338295'},
#  'date': '1546762940243'}

# %%
print(currency.keys())
# Out:
# dict_keys(['BTC', 'ETH', 'DASH', 'LTC', 'ETC', 'XRP', 'BCH', 'XMR', 'ZEC', 'QTUM', 'BTG', 'EOS', 'ICX', 'VET', 'TRX', 'ELF', 'MITH', 'MCO', 'OMG', 'KNC', 'GNT', 'ZIL', 'ETHOS', 'PAY', 'WAX', 'POWR', 'LRC', 'GTO', 'STEEM', 'STRAT', 'ZRX', 'REP', 'AE', 'XEM', 'SNT', 'ADA', 'PPT', 'CTXC', 'CMT', 'THETA', 'WTC', 'ITC', 'TRUE', 'ABT', 'RNT', 'PLY', 'WAVES', 'LINK', 'ENJ', 'PST', 'SALT', 'RDN', 'LOOM', 'BHPC', 'PIVX', 'INS', 'BCD', 'BZNT', 'XLM', 'OCN', 'BSV', 'TMTG', 'BAT', 'WET', 'XVG', 'IOST', 'POLY', 'HC', 'MEETONE', 'ADD', 'HORUS', 'CHL', 'EOSDAC', 'BLACK', 'ROM', 'AMO', 'date'])

# %%
print(currency.values())
# Out:
# dict_values([{'opening_price': '4315000', 'closing_price': '4293000', 'min_price': '4269000', 'max_price': '4351000', 'average_price': '4307588.448', 'units_traded': '19921.28934084', 'volume_1day': '19921.28934084', 'volume_7day': '91870.8952106', 'buy_price': '4292000', 'sell_price': '4293000', '24H_fluctate': '-22000', '24H_fluctate_rate': '-0.50'}, {'opening_price': '175300', 'closing_price': '170700', 'min_price': '168300', 'max_price': '178300', 'average_price': '174032.0285', 'units_traded': '387305.81649341', 'volume_1day': '387305.81649341', 'volume_7day': '2610703.263192550329706921', 'buy_price': '170600', 'sell_price': '170700', '24H_fluctate': '-4600', '24H_fluctate_rate': '-2.62'}, {'opening_price': '90050', 'closing_price': '89600', 'min_price': '88600', 'max_price': '91050', 'average_price': '89642.2194', 'units_traded': '4089718.95060572', 'volume_1day': '4089718.95060572', 'volume_7day': '29643805.95865686', 'buy_price': '89300', 'sell_price': '89500', '24H_fluctate': '-450', '24H_fluctate_rate': '-0.49'}, {'opening_price': '37090', 'closing_price': '39580', 'min_price': '36750', 'max_price': '40780', 'average_price': '39412.4372', 'units_traded': '47745.40889459', 'volume_1day': '47745.40889459', 'volume_7day': '198174.94804281', 'buy_price': '39530', 'sell_price': '39630', '24H_fluctate': '2490', '24H_fluctate_rate': '6.71'}, {'opening_price': '5780', 'closing_price': '5800', 'min_price': '5715', 'max_price': '5895', 'average_price': '5803.0444', 'units_traded': '179037.43513871', 'volume_1day': '179037.43513871', 'volume_7day': '1502317.627635475096835958', 'buy_price': '5795', 'sell_price': '5800', '24H_fluctate': '20', '24H_fluctate_rate': '0.34'}, {'opening_price': '398', 'closing_price': '397', 'min_price': '395', 'max_price': '405', 'average_price': '399.3204', 'units_traded': '31144822.51642185', 'volume_1day': '31144822.51642185', 'volume_7day': '342836116.16366557', 'buy_price': '397', 'sell_price': '398', '24H_fluctate': '-1', '24H_fluctate_rate': '-0.25'}, {'opening_price': '176600', 'closing_price': '179000', 'min_price': '175400', 'max_price': '186200', 'average_price': '180305.5501', 'units_traded': '34805.06672542', 'volume_1day': '34805.06672542', 'volume_7day': '376500.40872308', 'buy_price': '178600', 'sell_price': '179000', '24H_fluctate': '2400', '24H_fluctate_rate': '1.35'}, {'opening_price': '56750', 'closing_price': '55950', 'min_price': '55150', 'max_price': '57100', 'average_price': '55978.441', 'units_traded': '13877782.03220731', 'volume_1day': '13877782.03220731', 'volume_7day': '85444311.553511623238', 'buy_price': '55900', 'sell_price': '55950', '24H_fluctate': '-800', '24H_fluctate_rate': '-1.40'}, {'opening_price': '65400', 'closing_price': '64700', 'min_price': '63800', 'max_price': '66950', 'average_price': '66270.0505', 'units_traded': '668643.03853151', 'volume_1day': '668643.03853151', 'volume_7day': '14770168.22083555', 'buy_price': '64400', 'sell_price': '64600', '24H_fluctate': '-700', '24H_fluctate_rate': '-1.07'}, {'opening_price': '2520', 'closing_price': '2499', 'min_price': '2485', 'max_price': '2561', 'average_price': '2520.7361', 'units_traded': '315160.07063675', 'volume_1day': '315160.07063675', 'volume_7day': '2665322.78697243', 'buy_price': '2495', 'sell_price': '2499', '24H_fluctate': '-21', '24H_fluctate_rate': '-0.83'}, {'opening_price': '14500', 'closing_price': '14440', 'min_price': '14310', 'max_price': '14590', 'average_price': '14498.729', 'units_traded': '16697933.17361039', 'volume_1day': '16697933.17361039', 'volume_7day': '120817940.74730103', 'buy_price': '14440', 'sell_price': '14490', '24H_fluctate': '-60', '24H_fluctate_rate': '-0.41'}, {'opening_price': '3013', 'closing_price': '2990', 'min_price': '2965', 'max_price': '3085', 'average_price': '3022.3997', 'units_traded': '1563294.38941196', 'volume_1day': '1563294.38941196', 'volume_7day': '19744253.68625633', 'buy_price': '2990', 'sell_price': '2994', '24H_fluctate': '-23', '24H_fluctate_ ...

# %%
print(currency['ABT'])
# Out:
# {'opening_price': '91.9', 'closing_price': '90.5', 'min_price': '86.5', 'max_price': '92.9', 'average_price': '90.6377', 'units_traded': '1229767.29325293', 'volume_1day': '1229767.29325293', 'volume_7day': '54612530.076146308094807586', 'buy_price': '90.4', 'sell_price': '91.2', '24H_fluctate': '-1.4', '24H_fluctate_rate': '-1.52'}

# %%
# 좋은 풀이
for key, value in currency.items():
    if type(value) == type(dict()):
        bdp = float(value['max_price'])- float(value['min_price'])
        if float(value['opening_price']) + bdp > float(value['max_price']):
            print(f'{key:5} 상승장')
        else:
            print(f'{key:5} 하락장')
# Out:
# BTC   상승장
# ETH   상승장
# DASH  상승장
# LTC   상승장
# ETC   상승장
# XRP   상승장
# BCH   상승장
# XMR   상승장
# ZEC   상승장
# QTUM  상승장
# BTG   상승장
# EOS   상승장
# ICX   상승장
# VET   상승장
# TRX   상승장
# ELF   상승장
# MITH  상승장
# MCO   상승장
# OMG   상승장
# KNC   상승장
# GNT   상승장
# ZIL   상승장
# ETHOS 상승장
# PAY   상승장
# WAX   상승장
# POWR  상승장
# LRC   상승장
# GTO   상승장
# STEEM 상승장
# STRAT 상승장
# ZRX   상승장
# REP   상승장
# AE    상승장
# XEM   상승장
# SNT   하락장
# ADA   상승장
# PPT   상승장
# CTXC  상승장
# CMT   상승장
# THETA 상승장
# WTC   상승장
# ITC   상승장
# TRUE  상승장
# ABT   상승장
# RNT   상승장
# PLY   상승장
# WAVES 상승장
# LINK  상승장
# ENJ   상승장
# PST   상승장
# SALT  하락장
# RDN   상승장
# LOOM  상승장
# BHPC  상승장
# PIVX  상승장
# INS   상승장
# BCD   상승장
# BZNT  상승장
# XLM   상승장
# OCN   하락장
# BSV   상승장
# TMTG  상승장
# BAT   상승장
# WET   상승장
# XVG   하락장
# IOST  상승장
# POLY  상승장
# HC    상승장
# ROM   하락장
# AMO   상승장
